# %% [markdown]
# <a href="https://colab.research.google.com/github/kishorekubendiran/Library_management_system/blob/main/Library_management_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dnspython
# !pip install pymongo[srv] 
import pymongo
import re
import datetime as dt
import pandas as pd
client = pymongo.MongoClient("mongodb+srv://kishorekubendiran:Kishore@cluster0.tywig9w.mongodb.net/?retryWrites=true&w=majority")
db=client.library_management

st=db.student_register
#st.drop()

iu=db.issued
#iu.drop()

iv=db.inventory
#iv.drop()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
print("_________________________________________________________________________\n")
print("!...........................Welcome to Library..........................!")
print("_________________________________________________________________________\n\n")
def main_menu():
  penality_update()
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>>>     .....Main menu.....     <<<<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------")
  print("<<>> If your are admin------------------------------------->enter '''1'''")
  print("<<>> If your are Student----------------------------------->enter '''2'''")
  print("-------------------------------------------------------------------------")
  press=input("\nPlease enter here: ")
  if press=="1" or press=="2":
    if press=="1":
      admin_login()
    elif press=="2":
      student_page()
  else:
    print("_________________________________________________________________________\n")
    print("                   .....Please enter a valid number.....                    ")   
    print("                .....You have entered a invalid number.....             ")
    print("_________________________________________________________________________\n")
    print("")
    print("")
    main_menu()

def admin_login():
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>     .....Admin log in page.....     <<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n")
  _a=input("<<>> Enter admin username: ")
  if _a=="admin":
    _p=input("<<>> Enter admin password: ")
    if _p=="admin":
      print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
      print("                       .....Welcome admin!!!.....                    ")
      print("                       .....Have a happy day.....                   ")
      print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")
      admin_menu()
    else:
      print("_________________________________________________________________________\n")
      print("                     .....Invalid password.....                          ")   
      print("              .....Please enter a valid password.....                    ")
      print("_________________________________________________________________________\n")
      admin_login()
  else:
    print("_________________________________________________________________________\n")
    print("                       .....Invalid password.....                          ")   
    print("              .....Please enter the correct username.....                    ")
    print("_________________________________________________________________________\n")
    admin_login()

def admin_menu():
  print("\n-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>     .....Admin menu page.....     <<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n")
  print("-------------------------------------------------------------------------")
  print("<> To Add new book to inventory---------------------------->enter '''1'''")
  print("<> To Edit book name are author name from inventory-------->enter '''2'''")
  print("<> To Delete book from inventory--------------------------->enter '''3'''")
  print("<> To issue book from inventory---------------------------->enter '''4'''")
  print("<> To Receive issued book---------------------------------->enter '''5'''")
  print("<> To View available books--------------------------------->enter '''6'''")
  print("<> To view issued books------------------------------------>enter '''7'''")
  print("<> To collect penality------------------------------------->enter '''8'''")
  print("<> To exit to main menu------------------------------------>enter '''0'''")
  print("-------------------------------------------------------------------------\n")

  i=input("Please enter here: ")
  if i=="1":
    add_book()
  elif i=="2":
    edit_book_inventory_book()
  elif i=="3":
    delete_inventory_book()
  elif i=="4":
    issue_book()
  elif i=="5":
    receive_book()
  elif i=="6":
    view_available_books()
  elif i=="7":
    view_issued_books()
  elif i=="8":
    a=input("<> Enter the student phone number: ")
    b=input("<> Enter the book ISBN number    : ")
    penality_collector(a,b)
  elif i=="0":
    main_menu()
  else:
    print("Enter a valid number")
    admin_menu()

def student_page():
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>     .....students Page.....     <<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------")
  print("<> If you are new student for registeration---------------->enter '''1'''")
  print("<> If you are already registered to login------------------>enter '''2'''")
  print("<> If you want to exit to the main menu-------------------->enter '''3'''")
  print("-------------------------------------------------------------------------")
  press=input("\nPlease enter here: ")
  if press=="1":
    register_page()
  elif press=="2":
    student_login()
  elif press=="3":
    main_menu()
  else:
    print("You have entered a invalid number")
    print("Please enter a valid number")
    student_page()

def register_page():
  print("\n-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>     .....student Register.....     <<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n")
  print("Hello Students,\n\n          This message is from the admin of the Library. I kindly request\nall the new students to register your details with us so in future you\ncan get books from library without any stuggle.")
  print("\nTerms & Condition:")
  print("------------------")
  print("\n <> The barrowed books must be returned or renewed with in 15 days are \n    you need to pay a fine of Rs.20/per day.")
  print(" <> If the book got missed are damaged while the book is with you you \n    need to pay 80% original price of the book as fine.")
  print(" <> Regarding any query are to report any damage of the book contact \n    Library admin.")
  print("\nBy,\nAdmin.\n")
  print("\n-------------------------------------------------------------------------")
  print("<> If you accept all the Terms & Condition----------------->enter '''1'''")
  print("<> Are to exit--------------------------------------------->enter '''0'''")
  print("-------------------------------------------------------------------------\n")
  i=input("\nPlease enter here: ")
  if i=="1":
    print("_________________________________________________________________________\n")
    print("         ...Happy Learning & Keep Learning,All the best!!!...")           
    print("_________________________________________________________________________\n")
    student_register()
  else:
    print("Thanks for visiting Library")
    main_menu()

def student_register():
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>>     .....Register page.....     <<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n\n")
  d={
    '_id':phone_number(),
    'name':student_name(),
    'roll_no':student_roll_no(),
    'department':department_(),
    'mail_id':mail_id(),
    'password':password(),
    }
  st.insert_one(d)
  print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
  print("            .....Your details has been added successfully.....            ")
  print("                            .....THANK YOU.....                          ")
  print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>     .....Student menu page.....     <<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n")
  print("\n-------------------------------------------------------------------------")
  print("<> To see available books in library----------------------->enter '''1'''")
  print("<> To move to student page--------------------------------->enter '''2'''")
  print("<> If you want to search for a book------------------------>enter '''3'''")
  print("<> To exit to main menu page------------------------------->enter '''0'''")
  print("-------------------------------------------------------------------------\n")
  i=input("Please enter here: ")
  if i=="1":
    view_available_books()
  elif i=="2":
    student_page()
  elif i=="3":
    search_book()
  else:
    main_menu()

def student_login():
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>     .....student Login.....     <<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n")
  _id=input("<> Enter your registered phone number : ")
  if st.find_one({'_id':{'$eq':_id}}):
    password=input("<> Enter your password                : ")
    if st.find_one({'$and':[{'_id':{'$eq':_id}},{'password':{'$eq':password}}]}):
      print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
      print("              .....Your has been logged in successfully.....             ")
      print("                            .....THANK YOU.....                          ")
      print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")
      print("-------------------------------------------------------------------------")
      print(">>>>>>>>>>>>>>>>>     .....Student menu page.....     <<<<<<<<<<<<<<<<<<<")
      print("-------------------------------------------------------------------------\n")
      print("-------------------------------------------------------------------------")
      print("<> To see available books in library----------------------->enter '''1'''")
      print("<> To see my list of barrowed books------------------------>enter '''2'''")
      print("<> If you want to search for a book------------------------>enter '''3'''")
      print("<> To move to student page--------------------------------->enter '''4'''")
      print("<> To exit to main menu page------------------------------->enter '''0'''")
      print("-------------------------------------------------------------------------\n")
      i=input("Please enter here: ")
      if i=="1":
        view_available_books()
      elif i=="2":
        print("-------------------------------------------------------------------------")
        print(">>>>>>>>>>>>>>>>     .....Barrowed books list.....     <<<<<<<<<<<<<<<<<<")
        print("-------------------------------------------------------------------------\n")
        u=iu.find({"username":_id},{"_id":0,"title":1 , "Penality":1, "issue_date":1,"date_to_return":1})
        ij=pd.DataFrame(u)
        print(ij)
        print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
        print("                            .....THANK YOU.....                          ")
        print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")
      elif i=="3":
        search_book()
      elif i=="4":
        student_page()
      else:
        main_menu()
    else:
      print("_________________________________________________________________________\n")
      print("                .....you have entered wrong password.....                ")
      print("_________________________________________________________________________\n")
      forgot_password=input("<> Forgot password please enter (y/n): ")
      if (forgot_password == "y") or (forgot_password =="Y"):
        _i=input("Enter your registered phone number: ")
        p=st.find({'_id':_i},{'_id':1,'password':1})
        for a in p:
          print(a) 
      else:
        print("_________________________________________________________________________\n")
        print("                       .....please enter again.....                      ")
        print("_________________________________________________________________________\n")
        student_login()
  else:
    print("_________________________________________________________________________\n")
    print("                .....Entered phone number does not exist.....            ")
    print("          .....please enter correct registered number to login.....      ")
    print("_________________________________________________________________________\n")
    print("-------------------------------------------------------------------------")
    print("<> To enter correct registered phone number---------------->enter '''1'''")
    print("<> To register as new student------------------------------>enter '''2'''")
    print("<> If you want to exit to main menu------------------------>enter '''3'''")
    print("-------------------------------------------------------------------------\n")
    i=input("Please enter here: ")
    if (i=="1"):
      student_login()
    elif (i=="2"):
      student_register()
    elif (i=="3"):
      main_menu()
    else:
      print("_________________________________________________________________________\n")
      print("               .....You have entered a invalid number.....               ")
      print("_________________________________________________________________________\n")
      student_page()

def phone_number():
  i=0
  while(i==0):
    print("  '''The phone number must start with 6-9 & should contain 10 digits'''")
    print("  ---------------------------------------------------------------------\n")
    phone_number1=input("<> Enter your phone number   : ")
    _phone_number="[6789][0-9]{9}$"
    if st.find_one({'_id': {'$eq':phone_number1}}):
      print("_________________________________________________________________________\n")
      print("            .....The entered phone number already exists.....            ")
      print("             .....Please enter a different phone number.....             ")
      print("_________________________________________________________________________\n")
      i=0
    else:
      if re.match(_phone_number,phone_number1):
        i=1
        if (phone_number is not None):
          return(phone_number1)
      else:
        i=0        
        print("_________________________________________________________________________\n")
        print("              .....Please enter the valid phone number.....              ")
        print("_________________________________________________________________________\n")

def student_name():
  i=0
  while(i==0):
    print("\n""       '''Name must be in format of [Kishore K] or [Yukeshan k]'''         ")
    print("  ---------------------------------------------------------------------\n")
    name=input("<> Enter your name           : ")
    _name="[A-Z a-z \._-]{2,25}$"
    if re.match(_name,name):
      i=1
      if (student_name is not None):
        return(name)
    else:
      i=0
      print("_________________________________________________________________________\n")
      print("                  .....Please enter a valid name.....                    ")
      print("_________________________________________________________________________\n")

def student_roll_no():
  i=0
  while(i==0):
    print("\n""           '''Roll number must be in format of [MECHAA0003]'''         ")
    print("  ---------------------------------------------------------------------\n")
    roll_no=input("<> Enter your roll number    :  ")
    _roll_no="[A-Z]{6}[0-9]{4}$"
    if re.match(_roll_no,roll_no):
      i=1
      if (student_roll_no is not None):
        return(roll_no)
    else:
      i=0
      print("_________________________________________________________________________\n")
      print("             .....Please enter the valid roll number.....                ")
      print("_________________________________________________________________________\n")

def department_():
  i=0
  while(i==0):
    print("\n""        '''Department name must be in format of [Mech] or [B.Sc]'''         ")
    print("  ---------------------------------------------------------------------\n")
    department=input("<> Enter your department name: ")
    _department="[^0-9][\-\.]?[A-Z a-z]{2,7}$"
    if re.match(_department,department):
      i=1
      if (department_ is not None):
        return(department)
    else:
      i=0
      print("_________________________________________________________________________\n")
      print("             .....Please enter the valid department.....                ")
      print("_________________________________________________________________________\n")

def mail_id():
  i=0
  while(i==0):
    print("\n""           '''Mail must be in format of [kishore123@gmail.com]'''         ")
    print("  ---------------------------------------------------------------------\n")
    mail=input("<> Enter your user Email id  : ")
    _mail="^[a-z A-Z]+[\._]?[a-z A-Z 0-9 \._-]+[@]\w+[A-Z a-z]+[.][A-Z a-z]{2,3}$"
    if st.find_one({'mail': {'$eq':mail}}):
      print("_________________________________________________________________________\n")
      print("               .....The entered mail id already exists.....              ")
      print("                .....Please enter a different mail id.....               ")
      print("_________________________________________________________________________\n")
      i=0
    else:
      if re.match(_mail,mail):
        i=1
        if (mail_id is not None):
          return(mail)
      else:
        i=0
        print("_________________________________________________________________________\n")
        print("                .....Please enter the valid Email id.....                ")
        print("_________________________________________________________________________\n")


def password():
  i=0
  while(i==0):
    print("\n""  '''Password must contain 1-captial,numeric,lower,special character'''")
    print("               '''password format must be [kishore@123]'''         ")
    print("  ---------------------------------------------------------------------\n")
    password1=input("<> Enter your password       : ")
    _password="^(?=.*[a-z])(?=.*[A-Z])(?=.*[0-9])(?=.*[^A-Za-z0-9])(?=.{6,16})"
    if re.match(_password, password1) and  6<len(password1)<16:
      i=1
      if (password is not None):
        return(password1)
    else:
      i=0
      print("_________________________________________________________________________\n")
      print("                     .....Invalid password.....                          ")   
      print("              .....Please enter a valid password.....                    ")
      print("_________________________________________________________________________\n")

def view_available_books():
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>     .....Available books list.....     <<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n")
  mylist=db.inventory.find().sort("ISBN number")
  mylist=pd.DataFrame(mylist)
  print(mylist)
  print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
  print("                            .....THANK YOU.....                          ")
  print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")

def search_book():
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>     .....Search books.....     <<<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n")
  name1=input("<> Enter the Book Title or Book Author name: ")
  t={"$or":[{"Book Title":name1},{"Book Author":name1}]}
  t=iv.find_one(t,{"_id":1,"Book Author":1,"Book Title":1})
  if (t!=None):
    t1=pd.DataFrame(t, index=[0])
    print(t1)
    print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
    print("                            .....THANK YOU.....                          ")
    print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")

  else:
    print("Not Found \n")

def penality_update():
  p=iu.find({"penality_paid":0 , "received":0})
  for i in p:
    d=dt.datetime.now() - i['date_to_return']
    if (d.days>0):
      pe=d.days*20
      j={"$set":{"penality":pe}}
      iu.update_one({"_id":i["_id"]},j)      

def isbn_number():
  i=0
  while(i==0):
    print("\n""            '''ISBN number must be in format of [12345]'''         ")
    print("  ---------------------------------------------------------------------\n")
    isbn=input("<> Enter the ISBN 5 digit number: ")
    _isbn="[0-9]{5}"
    if iv.find_one({"_id":{"$eq":isbn}}):
      print("_________________________________________________________________________\n")
      print("              .....The entered ISBN number already exists.....          ")   
      print("_________________________________________________________________________\n")
    else:
      if re.match(_isbn,isbn) and len(isbn)==5:
        i=1
        if (isbn_number is not None):
          return(isbn)
      else:
        print("_________________________________________________________________________\n")
        print("                      .....Invalid ISBN number.....                     ")   
        print("            .....Please enter a valid 5 digit ISBN number.....          ")
        print("_________________________________________________________________________\n")
        i=0

def add_book():
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>>>>     .....Add book.....     <<<<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n")
  u=int(input("<> How many books do you want to add: "))
  k=1
  if(u>=1):
    while(k<=u):
      d={
        "_id":isbn_number(),
        "Book Title":input("<> Enter the Book Title         :"),
        "Book Author":input("<> Enter the Book Author        :")
        }
      iv.insert_one(d)
      k=k+1
    print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
    print("               .....The books as been added successfully.....             ")
    print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
  else:
    print("_________________________________________________________________________\n")
    print("              .....Please enter the correct number.....                 ")
    print("_________________________________________________________________________\n")

def isbn__number():
  i=0
  while(i==0):
    isbn1=input("<> Enter the ISBN 5 digit number       : ")
    _isbn="[0-9]{5}"
    if re.match(_isbn,isbn1) and len(isbn1)==5:
      if iv.find_one({"_id":{"$eq":isbn1}}):
        i=1
        if (isbn_number is not None):
          return(isbn1)
      else:
        print("_________________________________________________________________________\n")
        print("                  .....Entered ISBN number not found.....               ")   
        print("            .....Please enter a valid 5 digit ISBN number.....          ")
        print("_________________________________________________________________________\n")
        i=0
    else:
      print("_________________________________________________________________________\n")
      print("                      .....Invalid ISBN number.....                     ")   
      print("            .....Please enter a valid 5 digit ISBN number.....          ")
      print("_________________________________________________________________________\n")
      i=0

def edit_book_inventory_book():
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>>>>     .....Edit page.....     <<<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n")
  print("-------------------------------------------------------------------------")
  print("<> To edit Book Title enter-------------------------------->enter '''1'''")
  print("<> To edit Book Author enter------------------------------->enter '''2'''")
  print("-------------------------------------------------------------------------\n")
  _i=input("Please enter here: ")
  you=isbn__number()
  if _i=="1" or _i=="2":
    if _i=="1":
      _book_title=input("<> Enter the changes in the Book Title :")
      q1={'_id': you}
      q2={'$set':{'Book Title':_book_title }}
      iv.update_one(q1,q2)
      print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
      print("               .....Changes as been updated successfully.....            ")
      print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")
    elif _i=="2":
      _book_author=input("<> Enter the changes in the Book Author:")
      q1={'_id': you}
      q2={'$set':{'Book Author':_book_author}}
      iv.update_one(q1,q2)
      print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
      print("               .....Changes as been updated successfully.....            ")
      print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")
    else:
      print("_________________________________________________________________________\n")
      print("                   .....Please enter a valid number.....                ")   
      print("                .....You have entered a invalid number.....             ")
      print("_________________________________________________________________________\n")
      i=0

def delete_inventory_book():
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>>>>     .....Delete page.....     <<<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n")
  you=isbn__number()
  iv.delete_one({'_id':you})
  print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
  print(" .....Entered ISBN details of the book as been deleted successfully..... ")
  print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")


def  issue_book():
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>>>     .....Issue book.....     <<<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n")
  a=input("<> Enter the student phone number         : ")
  tmp=st.find_one({'_id':a})
  if tmp != None:
    ct=iu.count_documents({'username':a})
    if(ct<5):
      b=input("<> Enter the ISBN number of the book      : ")
      so=iv.find_one({"_id":b})
      if so != None:
        print("\n""            '''Date must be in format of [YYYY-MM-DD]'''         ")
        print("  ---------------------------------------------------------------------\n")
        _date =input('<> Enter Date of Issue format-[YYYY-MM-DD]: ')
        date_="^\d{4}\-(0[1-9]|1[012])\-(0[1-9]|[12][0-9]|3[01])$"
        if re.match(date_,_date):
          date = dt.datetime.strptime((_date),'%Y-%m-%d')
          data ={
                        'username' : a,
                        'isbn' : b,
                        'title' : so['Book Title'],
                        'author' : so['Book Author'],
                        'issue_date' : date,
                        'date_to_return' : date + dt.timedelta(days = 15),
                        'returned_date' : None,
                        'penality_paid' : 0,
                        'received':0
               }
          h=iu.insert_one(data)
          i=iv.delete_one({"_id":b})
          if h != None and i != None:
            print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
            print("                     .....Book issued successfully.....                   ")
            print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
          else:
            print("_________________________________________________________________________\n")
            print("                 .....The book was not issued properely.....            ")  
            print("                          .....Please try again.....                    ")
            print("_________________________________________________________________________\n")
            issue_book()
        else: 
          print("_________________________________________________________________________\n")
          print("                 .....Incorrect data Format YYYY-MM-DD.....            ")   
          print("_________________________________________________________________________\n")
          issue_book()
      else:
        print("_________________________________________________________________________\n")
        print("                 .....The book has been already issued.....            ")   
        print("                        .....Try any other books.....                  ")   
        print("_________________________________________________________________________\n")
        issue_book()
    else:
      print("_________________________________________________________________________\n")
      print("                    .....User has to return one book.....               ")   
      print("_________________________________________________________________________\n")
      admin_menu()    
  else:
    print("_________________________________________________________________________\n")
    print("                 .....The entered number does not exist.....            ")   
    print(" .....Tell the student to register are login with different number..... ")   
    print("_________________________________________________________________________\n")
    print("-------------------------------------------------------------------------")
    print("<> To go back to admin menu-------------------------------->enter '''1'''")
    print("<> To go back to issue book-------------------------------->enter '''2'''")
    print("<> To go back to main menu--------------------------------->enter '''0'''")
    print("-------------------------------------------------------------------------\n")
    i=input("Please enter here: ")
    if i=="1":
      admin_menu()
    elif i=="2":
      issue_book()
    elif i=="0":
      main_menu()
    else:
      print("_________________________________________________________________________\n")
      print("               .....you have entered a invalid number.....               ")
      print("_________________________________________________________________________\n")
      admin_menu()

def receive_book():
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>>     .....Receive book.....     <<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n")
  a=input("<> Enter the student phone number  : ")
  tmp=st.find_one({'_id':a})
  if tmp != None:
    b=input("<> Enter the ISBN number of the book: ")
    so=iu.find_one({"isbn":b,"username":a})
    if so != None:
      print("\n""         '''Date must be in format of [YYYY-MM-DD]'''         ")
      print("  ---------------------------------------------------------------------\n")
      _date =input('<> Enter book received date        : ')
      date_="^\d{4}\-(0[1-9]|1[012])\-(0[1-9]|[12][0-9]|3[01])$"
      if re.match(date_,_date):
        date = dt.datetime.strptime((_date),'%Y-%m-%d')
        diff = date - so['date_to_return']
        if diff.days <= 0:
          print("No penality pending",diff.days)
          data1={
            "_id":so["isbn"],
            "Book Title":so["title"],
            "Book Author":so["author"]
            }
          e=iv.insert_one(data1)
          d=iu.delete_one({"_id":so["_id"]})
          if (e!=None and d!=None):
            print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
            print("            .....Received and Added in inventory succesfully.....          ")
            print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
          else:
            print("_________________________________________________________________________\n")
            print("                 .....The book was not received properely.....            ")   
            print("_________________________________________________________________________\n")
            admin_menu()          
        else:
          print("_________________________________________________________________________\n")
          print("                      .....This student has Penality.....                 ")   
          print("_________________________________________________________________________\n") 
          penality_collector(a,b)
    else:
      print("incorrect details, please try again\n")
      receive_book()
  else:
    print("Incorrect phone number\n")
    receive_book()   

def penality_collector(username1,ISBN1):
  c=iu.find_one({"isbn":ISBN1,"username":username1})
  if c!=None:
     rs=c["penality"]
     print(rs,"Ruppees Penality\n")
     er=int(input("Please Enter the amount - "))
     d=er-rs
     if(d>=0):
       print("\nDear Admin, Please give",d,"rs to the student\n")
       data1={
           "_id":c["isbn"],
           "Book Title":c["title"],
           "Book Author":c["author"]
           }
       ed=iv.insert_one(data1)  
       de=iu.delete_one({"_id":c["_id"]}) 
       if(ed!=None and de!=None):
         print("\nPenality paid and Book is Received successfully and Book Added in Inventory successfully- Thanks!!\n")
       else:
         print("\nFailed Please Try Again") 
         admin_menu()
     else:
       d1=rs-er
       print("It is Less amount\nStudent have to pay remaining",d1,"rs to submit the book\n") 

def view_issued_books():
  print("-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>>     .....Issues books.....     <<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n")
  i=iu.find({},{"_id":0,"author":0,"returned_date":0,"penality_paid":0,"received":0}).sort("username")
  i=pd.DataFrame(i)
  print(i)
  print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
  print("                            .....THANK YOU.....                          ")
  print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")


main_menu()
# Out:
# _________________________________________________________________________
#
# !...........................Welcome to Library..........................!
# _________________________________________________________________________
#
#
# -------------------------------------------------------------------------
# >>>>>>>>>>>>>>>>>>>>>     .....Main menu.....     <<<<<<<<<<<<<<<<<<<<<<<
# -------------------------------------------------------------------------
# <<>> If your are admin------------------------------------->enter '''1'''
# <<>> If your are Student----------------------------------->enter '''2'''
# -------------------------------------------------------------------------
#
# Please enter here: 1
# -------------------------------------------------------------------------
# >>>>>>>>>>>>>>>>>     .....Admin log in page.....     <<<<<<<<<<<<<<<<<<<
# -------------------------------------------------------------------------
#
# <<>> Enter admin username: admin
# ...
